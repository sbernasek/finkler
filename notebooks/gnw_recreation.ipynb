# %%
import sys, os
paths = ('../',)
for p in paths:
    if p not in sys.path:
        sys.path.insert(0, p)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from modules.gnweaver import gnwData
from modules.visualization import ValidationAllSpecies, PlotAllTimeSeries
from rxndiffusion.simulate import MonteCarloSimulation
from rxndiffusion.solver.signals import cSquarePulse

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# load GNW data
path = '../data/networks2/'
data = gnwData(path)

# %% [markdown]
# # load specific simulation

# %%
# specify network
network_id = 0
sim_id = 'wt'

# load GNW simulation
gnw_sim = data[network_id][sim_id]

# load timeseries
gnw_ts = gnw_sim.get_timeseries()

# %% [markdown]
# # re-simulate

# %%
# run equivalent dimensional simulation
ts = gnw_sim.reproduce(num_trials=100)

# %%
fig = ValidationAllSpecies(gnw_ts, ts)
