# %%
# add paths to modules and solver directories
import sys, os
paths = ('../',)
for p in paths:
    if p not in sys.path:
        sys.path.insert(0, p)

from modules.gnw import Data
from modules.visualization import ValidateAll, ValidateSpecies, PlotAllTimeSeries
#from solver.simulate import MonteCarloSimulation
#from solver.solver.signals import cSquarePulse

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# load GNW data
path = '../data/networks2/'
data = Data(path)

# %% [markdown]
# # load specific simulation

# %%
# specify network
network_id = 0
sim_id = 'wt'

# load GNW simulation
gnw_sim = data[network_id][sim_id]

# load timeseries
gnw_ts = gnw_sim.get_timeseries()

# %% [markdown]
# # re-simulate

# %%
# run equivalent dimensional simulation
ts = gnw_sim.reproduce(num_trials=100, T=1, X=10, Y=100)

# %%
fig = ValidateAll(gnw_ts, ts)
